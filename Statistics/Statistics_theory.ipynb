# %% [markdown]
# <a href="https://colab.research.google.com/github/AKISHPOTHURI/DataScience/blob/main/Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Statistics**

# %% [markdown]
# **Statistics:**
# Statistics is the descipline that concerns the collection,organisizing,analysis, interpretation and presentation of data.
#
# **Statistics is two type:**
#
# 1.   Descriptive Statistics
# 2.   Inferential Statistics

# %% [markdown]
# **Descriptive Stats:**
# Descriptive Statistics describes the characteristics of a data set. It is a simple technique to describe, show and summarize data in a meaningful way. You simply choose a group you’re interested in, record data about the group, and then use summary statistics and graphs to describe the group properties.
#
# 1.   Analying data,Summarizing data and organizing data in the foam of Numbers and Graphs.
# 2.   Bar plot,Histogram,Pie-Chart,PDF,CDF, Normal distribution.
# 3. Measure of Central Tendency :
# Mean,Medial,Mode.
# 4. Measure of variance
# Standard deviation,Variance : standard deviation is square root of variance. variance is a measure of how far a value in a data set lies from the mean value.From Skewness(measures the degree of symmetric) also we can calculate the distribution of data.
#
# **Inferential Stats:**
# In Inferential Statistics, the focus is on making predictions about a large group of data based on a representative sample of the population. A random sample of data is considered from a population to describe and make inferences about the population.\
# Ex: Exit Poll
# 1.   Z Test/T Test/Chi Square Test -(Hypothesis) - Hypothesis is used to compare entire populations or assess relationships between variables using samples.
# 2.   Confidence Intervals - The main goal of inferential statistics is to estimate population parameters, which are mostly unknown or unknowable values. A confidence interval observes the variability in a statistic to draw an interval estimate for a parameter. Confidence intervals take uncertainty and sampling error into account to create a range of values within which the actual population value is estimated to fall.

# %% [markdown]
# **Randon Varibale:**
# A random variable is a real-valued function.
# Types of Random Variables:
#
# 1.   Discrete RV
# 2.   Continuous RV
# 3.   Mixed RV
#
# Probability Distribution of RV:\
# Probability distribution of a RV can be determined by calculationg the probability of occurrenceof every value in the range of the random variable.
# The PD is described for decrete and continuous RV in different ways.
#
# *Discrete Case:*\
# Whole number, not a floating numer like Tossing coin,No of bank accounts a person have. \
# eg:4,5,8,7 \
# x={0,1,2} \
# p(x)={0.25,.5,0.25} \
# ![PMF.png](data:image/png;base64,...)
# *   Probability mass function is used to describe the distribution (PMF)
# *   PMF can never be more than 1 or negative.
#
# *Continuous Case:*\
# ![PDF.png](data:image/png;base64,...) \
# With in a range of values.Can have any value. Like height of the group of 1000 people. \
# Ex : (decimal or whole number)
# like - 10, 10.6, 14.9 etc
# * Probability distribution function is used to describe the distribution (PDF).
# * PDF can never negative.
# * PDF must integrate t one over the entire range of a RV.
#
# *Cumulative Distribution of RV:* \
# ![CDF.png](data:image/png;base64,...)\
# Cummalative distribution is the summantion of PMF for discrete and PDF for continuous.
#
# * CDF is always a non-decreasing function.
# * CDF always lies between 0 and 1.

# %% [markdown]
# **Skewness:**
# It used to determine whether the data is symmetric or skewed. If the index is between -1 and 1, then the distribution is symmetric. If the index is no more than -1 then it is skewed to the left and if it is at least 1, then it is skewed to the right

# %% [markdown]
# # ****Distributions****

# %% [markdown]
# *Gaussian/Normal distribution:*
#
# probability distribution is symmetric about the mean, showing that data near the mean are more frequent in occurrence than data far from the mean.**Mean could be zero or any value.** \
# Notation : N ~ (mean,variance) \
# ![Normal.png](data:image/png;base64,...) \
# *Properties:* \
# * mean = mode = median
# * low variance distribution has the more data at the middle of the curve and vice versa.
# * many people call it the Bell Curve, as it is shaped like a bell.
# * No skew is present because perfectly centered around the mean(symmetric).
# * graph is symmetric about the mean.
# * With in 1 standard deviation of the mean value(mean-variance<=x<=mean+variance) 68% is present.
# * With in 2 standard deviations of the mean(mean-2variance<=x<=mean+2variance) 95% is present.
# * With in 3 standard deviations of the mean(mean-3variance<=x<=mean+3variance) 99.7% is present.

# %% [markdown]
# *Standard Noraml distribution:* \
# Standard normal distribution is the special type of distribution where mean should be zero and standard deviation should be one. \
#
# graph is same as normal distribution but the mean value should be one and difference between two consecutive points on the scale(x-axis) should be one.

# %% [markdown]
# *Log Normal Distribution :*
#
# The log-normal distribution is a right skewed continuous probability distribution, meaning it has a long tail towards the right.
# It is used for modelling various natural phenomena such as income distributions. \
# Notation : Lognormal(mean,variance) \
# ![log.png](data:image/png;base64,...) \
# *Properties:* \
# * Mode < median < mean
# * Right skewed
# * graph is not symmetric
# * It has long tail right side.
# * When we take the log it become normal distribution. \
#  log(X) = Y ==> X = e^Y
#  ![lognormal.png](data:image/png;base64,...)

# %% [markdown]
# *Power Law distribution:* \
# ![image.png](data:image/png;base64,...)
# The power law (also called the scaling law) states that a relative change in one quantity results in a proportional relative change in another.  \
# Ex: The simplest example of the law in action is a square; if you double the length of a side (say, from 2 to 4 inches) then the area will quadruple (from 4 to 16 inches squared). A power law distribution has the form Y = KX^a.
# *   X and Y are variables of interest
# *   a is the law’s exponent
# * k is a constant. \
#
# Properties: \
# * Right skewed distribution.
# * long tail distribution.
# * follows 80 - 20 effet.
# * PDF because of continuous values. \
#
# Other examples of phenomena with this type of distribution: \
# * Distribution of income,
# * Magnitude of earthquakes,
# * Size of cities according to population,
# * Size of corporations,
# * Trading volumes on the stock market,
# * word frequencies. \
#
# Similar Distributions and Laws: \
# A special type of the this type of distribution is the Pareto Principle (also called the Pareto Law), which is an unscientific “law” that states 80% of effects come from 20% of causes.

# %% [markdown]
# *Bernoulli distribution:* \
# The Bernoulli distribution is a discrete probability distribution, which means that it only considers discrete random variables. The descrete randon variable has finite or countable number of possible outcomes. \
#
# Notation: X ∼ Bernoulli (p) \
#
# ![image.png](data:image/png;base64,...)
#
# Properties: \
# * Mean is the expected value of the distribution denoted by p,
# E[x] = p.
# * The variance can be defined as the difference of the mean of p^2 and the square of the mean of p. \
# Mathematically, V[X] = p-p^2 = p(1-p).
# * Bernoulli distribution is a discrete probability distribution where the Bernoulli random variable can have only 0 or 1 as the outcome.
# * p is the probability of success and 1 - p is the probability of failure.
# * Bernoulli distribution is a special case of binomial distribution when only 1 trial is conducted.
# * graph is PMF.
#
# Application of Bernoulli Distribution:
# * The success or failure of a medical treatment
# * Transmission or non-transmission of a disease
# * A newborn child is male or female

# %% [markdown]
# *Binomial distribution:* \
# Binomial distribution is a probability distribution in statistics that summarizes the likelihood that a value will take one of two independent values under a given set of parameters or assumptions.
#
# The underlying assumptions of binomial distribution are that there is only one outcome for each trial, that each trial has the same probability of success, and that each trial is mutually exclusive or independent of one another.
#
# Formula: P(x:n,p) = (nCx)(xp^x)((1-p)^(n-x))
# * n is the number of trials (occurrences)
# * x is the number of successful trials
# * p is probability of success in a single trial
# * nCx is the combination of n and x. A combination is the number of ways to choose a sample of x elements from a set of n distinct objects where order does not matter and replacements are not allowed. Note that nCx=n!/(r!(n−r)!), where ! is factorial (so, 4! = 4 × 3 × 2 × 1).
#
# ![image.png](data:image/png;base64,...)
#
# Properties:
# * Mean of distribution is np.
# * Variance of the distribution is np(1-p).
# * The distribution is symmetric around the mean.
# * p > 0.5, the distribution is skewed to the left.
# *  p < 0.5, the distribution is skewed to the right.
# * graph has PMF.
# * The binomial distribution is the sum of a series of multiple independent and identically distributed Bernoulli trials. In a Bernoulli trial, the experiment is said to be random and can only have two possible outcomes: success or failure. \
# EX:Banks may use it to estimate the likelihood of a particular borrower defaulting or how much money to lend and the amount to keep in reserve. It’s also used in the insurance industry to determine policy pricing and to assess risk.

# %% [markdown]
# *Possion distribution:* \
# A Poisson distribution is a discrete probability distribution. It gives the probability of an event happening a certain number of times (k) within a given interval of time or space.
#
# The Poisson distribution has only one parameter, λ (lambda), which is the mean number of events. The graph below shows examples of Poisson distributions with different values of λ.
#
# Formula : p(X = k) = (e^-λ)(λ^k)/k!
# * X is a random variable following a Poisson distribution
# * k is the number of times an event occurs
# * P(X = k) is the probability that an event will occur k times
# * e is Euler’s constant (approximately 2.718)
# * lambda is the average number of times an event occurs
# * ! is the factorial function
#
# ![image.png](data:image/png;base64,...)
#
# Properties:
# * The mean of a Poisson distribution is λ.
# * The variance of a Poisson distribution is also λ.
# * graph is PMF.
#
# Ex: Website visitors per month , Text messages per hour

# %% [markdown]
# *Uniform distribution:* \
# Uniform distributions are probability distributions with equally likely outcomes. \
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...) \
# Uniform distribution has two types: \
# * continuous
# * discrete
#
# In a discrete uniform distribution, outcomes are discrete and have the same probability. \
# In a continuous uniform distribution, outcomes are continuous and infinite. \
# Formula : \
# P(x) = 1/n for discrete. \
# P(x)	=	{0 for x<a; 1/(b-a) for a<=x<=b; 0 for x>b for continuous
#
# *Properties:* \
# * graph is symmetric.
# * Skewness is zero.
#
# Ex: \
# A deck of cards has within it uniform distributions because the likelihood of drawing a heart, a club, a diamond, or a spade is equally likely. \
# A coin also has a uniform distribution because the probability of getting either heads or tails in a coin toss is the same.

# %% [markdown]
# *Exponential distribution:* \
# The exponential distribution is a continuous distribution that is commonly used to measure the expected time for an event to occur. \
#
# ![image.png](data:image/png;base64,...)
#
# *Formula : f(x|λ) = { λe^-λx for x>0; 0 for x<=0;*
# * λ is called the distribution rate.
# * X is exponential distribution.
#
# *Property :*
#
# * The exponential distribution is a “memoryless” distribution. Memoryless is a distribution characteristic that indicates the time for the next event does not depend on how much time has elapsed. For a memoryless process, the probability of an event happening one minute from now does not depend on when you start watching for the event.
# * The exponential distribution is a right-skewed continuous probability distribution that models variables in which small values occur more frequently than higher values.
# * mean = 1/λ.
# * variance = 1/λ^2
#
# Ex: The amount of time (beginning now) until an earthquake occurs has an exponential distribution. Other examples include the length of time, in minutes, of long distance business telephone calls, and the amount of time, in months, a car battery lasts.

# %% [markdown]
# *CHI Square distribution:* \
# A chi-square distribution is a continuous distribution with k
#  degrees of freedom. It is used to describe the distribution of a sum of squared random variables. It is also used to test the goodness of fit of a distribution of data. \
#  ![image.png](data:image/png;base64,...)
#
#                   probability mass distribution.
# *Properties:*
# * The chi-squared distribution is a continuous probability distribution with a skewed, non-normal shape.
# * Mean and variance: The mean of the chi-squared distribution is equal to the degrees of freedom(k), and the variance is equal to twice the degrees of freedom(2k).
# * The degrees of freedom must be a positive integer(had only one parameter k as degree of freedom).
# * graph is PDF because of continuous values.
#
# Ex: \
# Salary level of Employees and level of job satisfaction. \
# Association between training received and performance of sales men. \
# Credit worthiness of borrowers for personal loans and their age group. \
# Attitude ( Bearish, Neutral, Bullish) towards stock market and age of investors.
