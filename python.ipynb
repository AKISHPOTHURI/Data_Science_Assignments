# %% [markdown]
# Question 1: -
#
# Write a program that takes a string as input, and counts the frequency of each word in the string, there might
# be repeated characters in the string. Your task is to find the highest frequency and returns the length of the
# highest-frequency word.
#
# Note - You have to write at least 2 additional test cases in which your program will run successfully and provide
# an explanation for the same.
#
# Example input - string = “write write write all the number from from from 1 to 100”
#
# Example output - 5
#
# Explanation - From the given string we can note that the most frequent words are “write” and “from” and
# the maximum value of both the values is “write” and its corresponding length is 5

# %%
text = "write write write all the number from from from 1 to 100"
words = []
words = text.split()
wfreq = [words.count(w) for w in words]
keys_max = 0
vals_max = 0
for key, val in dict(zip(words,wfreq)).items():
    if val > vals_max:
        vals_max = val
        if len(key) > keys_max:
            keys_max = len(key)
print("max length of the most frequent word:",keys_max)
# Out:
# max length of the most frequent word: 5

# %% [markdown]
# Q-2
#
# Consider a string to be valid if all characters of the string appear the same number of times. It is also valid if
# he can remove just one character at the index in the string, and the remaining characters will occur the same
# number of times. Given a string, determine if it is valid. If so, return YES , otherwise return NO .
#
# Note - You have to write at least 2 additional test cases in which your program will run successfully and provide
# an explanation for the same.
#
# Example input 1 - s = “abc”. This is a valid string because frequencies are { “a”: 1, “b”: 1, “c”: 1 }
#
# Example output 1- YES
#
# Example input 2 - s “abccc”. This string is not valid as we can remove only 1 occurrence of “c”. That leaves
# character frequencies of { “a”: 1, “b”: 1 , “c”: 2 }
#
# Example output 2 - NO

# %%
text = input("Enter the string: ")
def isValid(s):
    d = {}
    for c in s:
        if c not in d:
            d[c] = 1
        else:
            d[c] += 1
    print(d)
    freq = {}
    for value in d.values():
        if value not in freq:
            freq[value] = 1
        else:
            freq[value] += 1

    if len(freq) == 1:
        return 'YES'

    if len(freq) == 2:
        min_freq = min(freq.keys())
        max_freq = max(freq.keys())
        if freq[max_freq] == 1 and (max_freq - min_freq) == 1:
            return 'YES'
        if freq[min_freq] == 1 and min_freq == 1:
            return 'YES'

    return 'NO'
isValid(text)
# Out:
# {'a': 1, 'b': 1, 'c': 3}
# 'NO'

# %% [markdown]
# Q-3
#
# Write a program, which would download the data from the provided link, and then read the data and convert
# that into properly structured data and return it in Excel format.
#
# Note - Write comments wherever necessary explaining the code written.
#
# Link - https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json
#
# Data Attributes - id: Identification Number - int num: Number of the
#
# ● Pokémon in the official Pokédex - int name: Pokémon name -
#
# ● string img: URL to an image of this Pokémon - string type:
#
# ● Pokémon type -string height: Pokémon height - float
#
# ● weight: Pokémon weight - float candy: type of candy used to evolve Pokémon or
# given
#
# ● when transferred - string candy_count: the amount of candies required to evolve
# - int
#
# ● egg: Number of kilometers to travel to hatch the egg - float spawn_chance:
#
# ● Percentage of spawn chance (NEW) - float avg_spawns: Number of this
# pokemon on 10.000 spawns (NEW) - int
#
# ● spawn_time: Spawns most active at the time on this field. Spawn times are the same for all
# time zones and are expressed in local time. (NEW) - “minutes: seconds” multipliers:
# Multiplier of Combat Power (CP) for calculating the CP after evolution See below - list of int
# weakness: Types of
#
# ● Pokémon this Pokémon is weak to - list of strings next_evolution: Number and Name of
# successive evolutions of Pokémon - list of dict prev_evolution: Number and Name of previous
# evolutions of Pokémon - - list of dict

# %%
import pandas as pd
df = pd.read_json('https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json')
df = pd.DataFrame(df)
df.head()
# Out:
#                                              pokemon
# 0  {'id': 1, 'num': '001', 'name': 'Bulbasaur', '...
# 1  {'id': 2, 'num': '002', 'name': 'Ivysaur', 'im...
# 2  {'id': 3, 'num': '003', 'name': 'Venusaur', 'i...
# 3  {'id': 4, 'num': '004', 'name': 'Charmander', ...
# 4  {'id': 5, 'num': '005', 'name': 'Charmeleon', ...

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq
import json as json
url = 'https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json'
uclient1 = uReq(url)
requests.get(url)
pokemonpage = uclient1.read()
dataPokemon = json.loads(pokemonpage)
df = pd.DataFrame(dataPokemon['pokemon'])
df.to_excel('pokemon.xlsx')

# %% [markdown]
# Question 4:
#
# Write a program to download the data from the link given below and then read the data and convert the into
# the proper structure and return it as a CSV file.
#
# Link - https://data.nasa.gov/resource/y77d-th95.json
#
# Note - Write code comments wherever needed for code understanding.

# %%
url = 'https://data.nasa.gov/resource/y77d-th95.json'
uclient1 = uReq(url)
requests.get(url)
data = uclient1.read()
data = json.loads(data)
df = pd.DataFrame(data)
df1=df['geolocation']
a = dict(df1)
a = pd.DataFrame(a)
b = pd.DataFrame(a.transpose())
df['geolocation_type'] = b['type']
df['geolocation_cordinates'] = b['coordinates']
df.drop(['geolocation', ':@computed_region_cbhk_fwbd',':@computed_region_nnqa_25f4'], axis=1, inplace=True)
nasaData = df
df.to_csv('nasa.csv')

# %%
df.dtypes
# Out:
# name                      object
# id                         int32
# nametype                  object
# recclass                  object
# mass                      object
# fall                      object
# year                      object
# reclat                    object
# reclong                   object
# geolocation_type          object
# geolocation_cordinates    object
# dtype: object

# %% [markdown]
# Question 5:
#
# Write a program to download the data from the given API link and then extract the following data with
# proper formatting
#
# Link - http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes
#
# Note - Write proper code comments wherever needed for the code understanding
#
# Excepted Output Data Attributes -
#
# ● id - int url - string
#
# ● name - string season
#
# ● - int number - int
#
# ● type - string airdate -
#
# ● date format airtime -
#
# ● 12-hour time format
#
# ● runtime - float
#
# ● average rating - float
#
# ● summary - string
#
# ● without html tags
#
# ● medium image link - string
#
# ● Original image link - string

# %%
url = 'http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes'
uclient1 = uReq(url)
requests.get(url)
tvmaze = uclient1.read()
data = json.loads(tvmaze)
data = data['_embedded']['episodes']
data
# Out:
# [{'id': 869671,
#   'url': 'https://www.tvmaze.com/episodes/869671/westworld-1x01-the-original',
#   'name': 'The Original',
#   'season': 1,
#   'number': 1,
#   'type': 'regular',
#   'airdate': '2016-10-02',
#   'airtime': '21:00',
#   'airstamp': '2016-10-03T01:00:00+00:00',
#   'runtime': 68,
#   'rating': {'average': 8},
#   'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_landscape/78/195475.jpg',
#    'original': 'https://static.tvmaze.com/uploads/images/original_untouched/78/195475.jpg'},
#   'summary': "<p>A woman named Dolores is a free spirit in the Old West... and unaware that she's actually an android, programmed to entertain rich guests seeking to act out their fantasies in an idealized vision of the 1880s. However, the people in charge soon realize that their androids are acting in ways that they didn't anticipate.</p>",
#   '_links': {'self': {'href': 'https://api.tvmaze.com/episodes/869671'},
# ...

# %%
url = 'http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes'
uclient1 = uReq(url)
requests.get(url)
tvmaze = uclient1.read()
data = json.loads(tvmaze)
data = data['_embedded']['episodes']

tvmazedata = pd.DataFrame(data)
rating = []
medium = []
Origin = []
for i in data:
    rating.append(i['rating']['average'])
    medium.append(i['image']['medium'])
    Origin.append(i['image']['original'])
tvmazedata['medium image link'] = (pd.DataFrame(medium)).astype('str')
tvmazedata['Original image link'] = (pd.DataFrame(Origin)).astype('str')
tvmazedata['average rating'] = (pd.DataFrame(rating)).astype('str')
tvmazedata.drop(['_links','image','rating'],axis=1,inplace=True)

tvmazedata['url'] = tvmazedata['url'].astype('str')
tvmazedata['name'] = tvmazedata['name'].astype('str')
tvmazedata['type'] = tvmazedata['type'].astype('str')
tvmazedata['airdate'] = pd.to_datetime(tvmazedata['airdate'])
tvmazedata['airtime'] = pd.to_datetime(tvmazedata['airtime'], format='%H:%M').dt.strftime('%I:%M %p')
tvmazedata['runtime'] = tvmazedata['runtime'].astype('float')
tvmazedata['average rating'] = tvmazedata['average rating'].astype('float')
tvmazedata['summary'] = tvmazedata['summary'].astype('str')
tvmazedata['medium image link'] = tvmazedata['medium image link'].astype('str')
tvmazedata['Original image link'] = tvmazedata['Original image link'].astype('str')

# %%
tvmazedata.head()
# Out:
#        id                                                url
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...  \
# 1  911201  https://www.tvmaze.com/episodes/911201/westwor...
# 2  911204  https://www.tvmaze.com/episodes/911204/westwor...
# 3  911205  https://www.tvmaze.com/episodes/911205/westwor...
# 4  927174  https://www.tvmaze.com/episodes/927174/westwor...
#
#                 name  season  number     type    airdate   airtime
# 0       The Original       1       1  regular 2016-10-02  09:00 PM  \
# 1           Chestnut       1       2  regular 2016-10-09  09:00 PM
# 2          The Stray       1       3  regular 2016-10-16  09:00 PM
# 3  Dissonance Theory       1       4  regular 2016-10-23  09:00 PM
# 4        Contrapasso       1       5  regular 2016-10-30  09:00 PM
#
#                     airstamp  runtime
# 0  2016-10-03T01:00:00+00:00     68.0  \
# 1  2016-10-10T01:00:00+00:00     60.0
# 2  2016-10-17T01:00:00+00:00     60.0
# ...

# %% [markdown]
# Question 6 -
#
# Using the data from Question 3, write code to analyze the data and answer the following questions Note
#
# 1.Draw plots to demonstrate the analysis for the following questions for better visualizations.
#
# 2.Write code comments wherever required for code understanding
#
# Insights to be drawn -
#
# ● Get all Pokemons whose spawn rate is less than 5%
#
# ● Get all Pokemons that have less than 4 weaknesses
#
# ● Get all Pokemons that have no multipliers at all
#
# ● Get all Pokemons that do not have more than 2 evolutions
#
# ● Get all Pokemons whose spawn time is less than 300 seconds.
#
# Note - spawn time format is "05:32”, so assume “minute: second” format and perform the analysis.
#
# ● Get all Pokemon who have more than two types of capabilities

# %%
# Get all Pokemons whose spawn rate is less than 5%
data = pd.read_excel('pokemon.xlsx')
data.head()
# Out:
#    Unnamed: 0  id  num        name
# 0           0   1    1   Bulbasaur  \
# 1           1   2    2     Ivysaur
# 2           2   3    3    Venusaur
# 3           3   4    4  Charmander
# 4           4   5    5  Charmeleon
#
#                                                 img                 type
# 0  http://www.serebii.net/pokemongo/pokemon/001.png  ['Grass', 'Poison']  \
# 1  http://www.serebii.net/pokemongo/pokemon/002.png  ['Grass', 'Poison']
# 2  http://www.serebii.net/pokemongo/pokemon/003.png  ['Grass', 'Poison']
# 3  http://www.serebii.net/pokemongo/pokemon/004.png             ['Fire']
# 4  http://www.serebii.net/pokemongo/pokemon/005.png             ['Fire']
#
#    height    weight             candy  candy_count          egg  spawn_chance
# 0  0.71 m    6.9 kg   Bulbasaur Candy         25.0         2 km         0.690  \
# 1  0.99 m   13.0 kg   Bulbasaur Candy        100.0  Not in Eggs         0.042
# ...

# %%
#Get all Pokemons that have less than 4 weaknesses
import matplotlib.pyplot as plt
data = pd.read_excel('pokemon.xlsx')
weakness_count = []
for i in dataPokemon['pokemon']:
    for i,j in i.items():
        if i == "weaknesses":
            weakness_count.append(len(j))
data['weakness_count'] = weakness_count
data = data[data['weakness_count'] < 4]
plt.bar(data['name'],data['weakness_count'])
# Out:
# <BarContainer object of 102 artists>

# %%
#Get all Pokemons whose spawn rate is less than 5%
data['avg_spawns'] = data['avg_spawns'].astype('float')
plt.bar(data['name'],data['avg_spawns']) # plot for whole avg_spawn
data_5 = data[data['avg_spawns']<5]
# Out:
# <BarContainer object of 67 artists>

# %%
plt.bar(data_5['name'],data_5['avg_spawns']) #plot for rate of spawn is less than 5
# Out:
# <BarContainer object of 67 artists>

# %%
# Get all Pokemons that have no multipliers at all
data = data[data['multipliers'].isnull()]
data['name']
# Out:
# 2        Venusaur
# 5       Charizard
# 8       Blastoise
# 11     Butterfree
# 14       Beedrill
#           ...
# 144        Zapdos
# 145       Moltres
# 148     Dragonite
# 149        Mewtwo
# 150           Mew
# Name: name, Length: 81, dtype: object

# %%
# Get all Pokemons that do not have more than 2 evolutions
a = data[data['prev_evolution'].isnull()]
b = data[data['next_evolution'].isnull()]
c = []
d = []
c = a['name']
d= b['name']
list(set(c+d))
# Out:
# [nan,
#  'TangelaTangela',
#  'PorygonPorygon',
#  'LickitungLickitung',
#  'PinsirPinsir',
#  'MagmarMagmar',
#  'HitmonleeHitmonlee',
#  'ArticunoArticuno',
#  'ScytherScyther',
#  'OnixOnix',
#  'HitmonchanHitmonchan',
#  'LaprasLapras',
#  'MewtwoMewtwo',
#  'TaurosTauros',
#  'SnorlaxSnorlax',
#  'MoltresMoltres',
#  'ElectabuzzElectabuzz',
#  'JynxJynx',
#  'MewMew',
#  "Farfetch'dFarfetch'd",
#  'ChanseyChansey',
#  'ZapdosZapdos',
#  'AerodactylAerodactyl',
#  'DittoDitto',
#  'Mr. MimeMr. Mime',
#  'KangaskhanKangaskhan']

# %%
# Get all Pokemons whose spawn time is less than 300 seconds.
lessName = []
for i,row in data[~data['spawn_time'].isnull()].iterrows():
    a,b = row['spawn_time'].split(":")
    if int(a) < 5: #5minutes is equal to 300 seconds
        lessName.append(row['name'])

lessName
# Out:
# ['Squirtle',
#  'Blastoise',
#  'Metapod',
#  'Weedle',
#  'Kakuna',
#  'Beedrill',
#  'Pidgey',
#  'Pidgeotto',
#  'Pidgeot',
#  'Rattata',
#  'Raticate',
#  'Fearow',
#  'Arbok',
#  'Pikachu',
#  'Sandshrew',
#  'Nidoran ♀ (Female)',
#  'Nidoran ♂ (Male)',
#  'Clefairy',
#  'Clefable',
#  'Ninetales',
#  'Golbat',
#  'Oddish',
#  'Paras',
#  'Parasect',
#  'Venonat',
#  'Diglett',
#  'Meowth',
#  'Persian',
#  'Psyduck',
#  'Growlithe',
#  'Arcanine',
#  'Poliwag',
#  'Poliwrath',
#  'Abra',
#  'Machop',
#  'Machamp',
#  'Bellsprout',
#  'Tentacool',
#  'Graveler',
#  'Ponyta',
#  'Rapidash',
#  'Slowbro',
#  'Magnemite',
#  "Farfetch'd",
#  'Dodrio',
#  'Muk',
#  'Cloyster',
#  'Gastly',
#  'Haunter',
#  'Gengar',
#  'Onix',
#  'Drowzee',
#  'Hypno',
#  'Krabby',
#  'Kingler',
#  'Voltorb',
#  'Electrode',
#  'Cubone',
#  'Marowak',
#  'Hitmonlee',
#  'Lickitung',
#  'Rhyhorn',
#  'Chansey',
#  'Kangaskhan',
#  'Horsea',
#  'Seadra',
#  'Goldeen',
#  'Mr. Mime',
#  'Electabuzz',
# ...

# %% [markdown]
# Question 7 -
#
# Using the data from Question 4, write code to analyze the data and answer the following questions Note -
#
# 1.Draw plots to demonstrate the analysis for the following questions for better visualizations
#
# 2.Write code comments wherever required for code understanding
#
# Insights to be drawn -
#
# ● Get all the Earth meteorites that fell before the year 2000
#
# ● Get all the earth meteorites co-ordinates who fell before the year 1970
#
# ● Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more
# than 10000kg

# %%
nasaData
# Out:
#           name     id nametype               recclass    mass  fall
# 0       Aachen      1    Valid                     L5      21  Fell  \
# 1       Aarhus      2    Valid                     H6     720  Fell
# 2         Abee      6    Valid                    EH4  107000  Fell
# 3     Acapulco     10    Valid            Acapulcoite    1914  Fell
# 4      Achiras    370    Valid                     L6     780  Fell
# ..         ...    ...      ...                    ...     ...   ...
# 995   Tirupati  24009    Valid                     H6     230  Fell
# 996    Tissint  54823    Valid  Martian (shergottite)    7000  Fell
# 997      Tjabe  24011    Valid                     H6   20000  Fell
# 998   Tjerebon  24012    Valid                     L5   16500  Fell
# 999  Tomakovka  24019    Valid                    LL6     600  Fell
#
#                         year      reclat      reclong geolocation_type
# 0    1880-01-01T00:00:00.000   50.775000     6.083330            Point  \
# ...

# %%
# Get all the Earth meteorites that fell before the year 2000
nasaData = nasaData[nasaData['year'].isnull() == False]
nasaData = nasaData[nasaData['name'].isnull() == False]
c = []
for i in nasaData['year']:
    c.append(i.split("-")[0])
nasaData['only_year'] = c
for i,row in nasaData.iterrows():
    if int(row['only_year']) < 2000:
        print(row['name'])

# %%
plt.bar(nasaData['name'],nasaData['only_year'])
# Out:
# <BarContainer object of 999 artists>

# %%
# Get all the earth meteorites co-ordinates who fell before the year 1970
for i,row in nasaData.iterrows():
    if int(row['only_year']) < 1970:
        print(row['geolocation_cordinates'])
# Out:
# [6.08333, 50.775]
# [10.23333, 56.18333]
# [-113, 54.21667]
# [-64.95, -33.16667]
# [71.8, 32.1]
# [95.16667, 44.83333]
# [0.61667, 44.21667]
# [-65.23333, -31.6]
# [-64.55, -30.86667]
# [8.38333, 19.08333]
# [2.33333, 50.66667]
# [35.05, 29.51667]
# [77.95, 29.71667]
# [8.43333, 8.91667]
# [39.51667, 24.41667]
# [4.08333, 44.11667]
# [11.01667, 44.65]
# [22.66667, 2]
# [-1.78333, 51.78333]
# [37.13333, 36.23333]
# [8.75, 44.88333]
# [31.81667, 50.95]
# [10.15, 45.26667]
# [-85.88333, 42.53333]
# [-105.31667, 26.96667]
# [78.25, 27.66667]
# [85.56667, 26.58333]
# [-70.75, 44.61667]
# [37.5, 48.7]
# [76.86667, 20.88333]
# [-0.55, 47.46667]
# [-44.31667, -22.96667]
# [39.71667, 9.53333]
# [-2.71667, 53.58333]
# [5.38333, 43.86667]
# [-66, -33]
# [-94.3, 38.5]
# [-60.66667, -31.41667]
# [9.03333, 42.45]
# [0.3, 52.05]
# [12.55, 43.03333]
# [80.625, 25.25417]
# [-103.66667, 20.06667]
# [-87, 34.75]
# [-96.15, 34.31667]
# [5.16667, 44.38333]
# [3.66667, 36.16667]
# [3.23333, 44.33333]
# ...

# %%
#Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more
# than 10000kg
nasaData = nasaData[nasaData['mass'].isnull() == False]
nasaData['mass'] = nasaData['mass'].astype('float')
nasaData[nasaData['mass'] > 10000]
# Out:
#            name     id nametype   recclass      mass  fall
# 2          Abee      6    Valid        EH4  107000.0  Fell  \
# 7          Agen    392    Valid         H5   30000.0  Fell
# 11          Aïr    424    Valid         L6   24000.0  Fell
# 16      Akyumak    433    Valid  Iron, IVA   50000.0  Fell
# 27   Alfianello    466    Valid         L6  228000.0  Fell
# ..          ...    ...      ...        ...       ...   ...
# 991   Tieschitz  23989    Valid     H/L3.6   28000.0  Fell
# 992      Tilden  23998    Valid         L6   74800.0  Fell
# 994    Timochin  24004    Valid         H5   65500.0  Fell
# 997       Tjabe  24011    Valid         H6   20000.0  Fell
# 998    Tjerebon  24012    Valid         L5   16500.0  Fell
#
#                         year     reclat      reclong geolocation_type
# 2    1952-01-01T00:00:00.000  54.216670  -113.000000            Point  \
# 7    1814-01-01T00:00:00.000  44.216670     0.616670            Point
# ...

# %% [markdown]
# Question 8 -
#
# Using the data from Question 5, write code the analyze the data and answer the following questions Note -
#
# 1.Draw plots to demonstrate the analysis for the following questions and better visualizations
#
# 2.Write code comments wherever required for code understanding
#
# Insights to be drawn -
#
# ● Get all the overall ratings for each season and using plots compare the ratings for all the
# seasons, like season 1 ratings, season 2, and so on.
#
# ● Get all the episode names, whose average rating is more than 8 for every season
#
# ● Get all the episode names that aired before May 2019
#
# ● Get the episode name from each season with the highest and lowest rating
#
# ● Get the summary for the most popular ( ratings ) episode in every season

# %%
# Get all the overall ratings for each season and using plots compare the ratings for all the
# seasons, like season 1 ratings, season 2, and so on.
season1 = []
season2 = []
season3 = []
season4 = []
for i,row in tvmazedata.iterrows():
    if row['season'] == 1:
        season1.append(row['average rating'])
    elif row['season'] == 2:
        season2.append(row['average rating'])
    elif row['season'] == 3:
        season3.append(row['average rating'])
    elif row['season'] == 4:
        season4.append(row['average rating'])
seasonOne,seasonTwo,seasonThree,seasonFour=pd.value_counts(tvmazedata['season'])

# %%
a = sum(season1)/seasonOne
b = sum(season2)/seasonTwo
c = sum(season3)/seasonThree
d = sum(season4)/seasonFour
print("Overall average of whole seasons: season1: {}, season2: {}, season3: {}, season4: {}".format(a,b,c,d))
# Out:
# Overall average of whole seasons: season1: 8.09, season2: 8.0, season3: 7.775, season4: 7.5375000000000005

# %%
plt.bar(tvmazedata['season'],tvmazedata['average rating'])
#y axis is average rating and x sxis is seasons.
# Out:
# <BarContainer object of 36 artists>

# %%
# Get all the episode names, whose average rating is more than 8 for every season
tvmazedata[tvmazedata['average rating'] > 8]['name']
# Out:
# 6                 Trompe L'Oeil
# 8     The Well-Tempered Clavier
# 9            The Bicameral Mind
# 17                      Kiksuya
# 18              Vanishing Point
# 19                The Passenger
# Name: name, dtype: object

# %%
# Get all the episode names that aired before May 2019
tvmazedata['air_year'] = pd.DatetimeIndex(tvmazedata['airdate']).year
tvmazedata['air_month'] = pd.DatetimeIndex(tvmazedata['airdate']).month
for i, row in tvmazedata.iterrows():
    if row['air_year'] < 2019 and row['air_month'] < 5:
        print(row['name'])
# Out:
# Journey Into Night
# Reunion

# %%
# Get the episode name from each season with the highest and lowest rating
##storing all seasons separatly
seasonOne = tvmazedata[tvmazedata['season'] == 1]
seasonTwo = tvmazedata[tvmazedata['season'] == 2]
seasonThree = tvmazedata[tvmazedata['season'] == 3]
seasonFour = tvmazedata[tvmazedata['season'] == 4]
##finding minimum and maximum average rating in separate season.
seasonOneMax = max(seasonOne['average rating'])
seasonOneMin = min(seasonOne['average rating'])
seasonTwoMax = max(seasonTwo['average rating'])
seasonTwoMin = min(seasonTwo['average rating'])
seasonThreeMax = max(seasonThree['average rating'])
seasonThreeMin = min(seasonThree['average rating'])
seasonFourMax = max(seasonFour['average rating'])
seasonFourMin = min(seasonFour['average rating'])

print("season1")
print("min rating episode name was -- {} -- and max rating episode name was -- {} --".format(seasonOne[seasonOne['average rating'] == seasonOneMin]['name'],seasonOne[seasonOne['average rating'] == seasonOneMax]['name']))
print("season2")
print("min rating episode name was --{}-- and max rating episode name was --{}--".format(seasonTwo[seasonTwo['average rating'] == seasonTwoMin]['name'],seasonTwo[seasonTwo['average rating'] == seasonTwoMax]['name']))
print("season3")
print("min rating episode name was --{}-- and max rating episode name was --{}--".format(seasonThree[seasonThree['average rating'] == seasonThreeMin]['name'],seasonThree[seasonThree['average rating'] == seasonThreeMax]['name']))
print("season4")
print("min rating episode name was --{}-- and max rating episode name was --{}--".format(seasonFour[seasonFour['average rating'] == seasonFourMin]['name'],seasonFour[seasonFour['average rating'] == seasonFourMax]['name']))
# Out:
# season1
# min rating episode name was -- 2    The Stray
# Name: name, dtype: object -- and max rating episode name was -- 9    The Bicameral Mind
# Name: name, dtype: object --
# season2
# min rating episode name was --14    Akane No Mai
# Name: name, dtype: object-- and max rating episode name was --17    Kiksuya
# Name: name, dtype: object--
# season3
# min rating episode name was --25    Decoherence
# 26    Passed Pawn
# Name: name, dtype: object-- and max rating episode name was --20            Parce Domine
# 23    The Mother of Exiles
# Name: name, dtype: object--
# season4
# min rating episode name was --28    The Auguries
# Name: name, dtype: object-- and max rating episode name was --32    Zhuangzi
# Name: name, dtype: object--

# %%
# Get the summary for the most popular ( ratings ) episode in every season
print("season1")
print("most popular (rating) column index and summary is {}".format(seasonOne[seasonOne['average rating'] == seasonOneMax]['summary']))
print("season2")
print("most popular (rating) column index and summary is {}".format(seasonTwo[seasonTwo['average rating'] == seasonTwoMax]['summary']))
print("season3")
print("most popular (rating) column index and summary is {}".format(seasonThree[seasonThree['average rating'] == seasonThreeMax]['summary']))
print("season4")
print("most popular (rating) column index and summary is {}".format(seasonFour[seasonFour['average rating'] == seasonFourMax]['summary']))
# Out:
# season1
# summary of most popular (rating) is 9    <p>Delores finds out the truth about William's...
# Name: summary, dtype: object
# season2
# summary of most popular (rating) is 17    <p>Another of Westworld's Host revolutionaries...
# Name: summary, dtype: object
# season3
# summary of most popular (rating) is 20    <p>If you're stuck in a loop, try walking in a...
# 23        <p>The truth doesn't always set you free.</p>
# Name: summary, dtype: object
# season4
# summary of most popular (rating) is 32    <p>God is bored.</p>
# Name: summary, dtype: object

# %% [markdown]
# Question 9 -
#
# Write a program to read the data from the following link, perform data analysis and answer the following
# questions
#
# Note -
#
# 1. Write code comments wherever required for code understanding
#
# Link - https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD
#
# Insights to be drawn -
#
# ● Get all the cars and their types that do not qualify for clean alternative fuel vehicle
#
# ● Get all TESLA cars with the model year, and model type made in Bothell City.
#
# ● Get all the cars that have an electric range of more than 100, and were made after
# 2015
#
# ● Draw plots to show the distribution between city and electric vehicle type

# %%
tesla = pd.read_csv("Electric_Vehicle_Population_Data.csv")
tesla.head() # total rows in this dataset is 130443.
# Out:
#    VIN (1-10)    County     City State  Postal Code  Model Year    Make
# 0  5YJXCAE26J    Yakima   Yakima    WA      98908.0        2018   TESLA  \
# 1  JHMZC5F37M    Kitsap  Poulsbo    WA      98370.0        2021   HONDA
# 2  5YJ3E1EB0K      King  Seattle    WA      98199.0        2019   TESLA
# 3  1N4AZ0CP5D      King  Seattle    WA      98119.0        2013  NISSAN
# 4  5YJSA1E21H  Thurston    Lacey    WA      98516.0        2017   TESLA
#
#      Model                   Electric Vehicle Type
# 0  MODEL X          Battery Electric Vehicle (BEV)  \
# 1  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  MODEL 3          Battery Electric Vehicle (BEV)
# 3     LEAF          Battery Electric Vehicle (BEV)
# 4  MODEL S          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range
# 0           Clean Alternative Fuel Vehicle Eligible             238  \
# 1           Clean Alternative Fuel Vehicle Eligible              47
# ...

# %%
tesla.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 3
# City                                                   3
# State                                                  0
# Postal Code                                            3
# Model Year                                             0
# Make                                                   0
# Model                                                222
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 305
# DOL Vehicle ID                                         0
# Vehicle Location                                      33
# Electric Utility                                       3
# ...

# %%
tesla = tesla.dropna(how='any',axis=0)
tesla.head() #All the null rows were dropped
# Out:
#    VIN (1-10)    County     City State  Postal Code  Model Year    Make
# 0  5YJXCAE26J    Yakima   Yakima    WA      98908.0        2018   TESLA  \
# 1  JHMZC5F37M    Kitsap  Poulsbo    WA      98370.0        2021   HONDA
# 2  5YJ3E1EB0K      King  Seattle    WA      98199.0        2019   TESLA
# 3  1N4AZ0CP5D      King  Seattle    WA      98119.0        2013  NISSAN
# 4  5YJSA1E21H  Thurston    Lacey    WA      98516.0        2017   TESLA
#
#      Model                   Electric Vehicle Type
# 0  MODEL X          Battery Electric Vehicle (BEV)  \
# 1  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  MODEL 3          Battery Electric Vehicle (BEV)
# 3     LEAF          Battery Electric Vehicle (BEV)
# 4  MODEL S          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range
# 0           Clean Alternative Fuel Vehicle Eligible             238  \
# 1           Clean Alternative Fuel Vehicle Eligible              47
# ...

# %%
tesla['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].unique()
# Out:
# array(['Clean Alternative Fuel Vehicle Eligible',
#        'Not eligible due to low battery range',
#        'Eligibility unknown as battery range has not been researched'],
#       dtype=object)

# %%
# Get all the cars and their types that do not qualify for clean alternative fuel vehicle
notEligibleCars = tesla[tesla['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] == 'Not eligible due to low battery range']
notEligibleCars[['Model Year','Make','Model']]
# Out:
#         Model Year    Make        Model
# 6             2016    FORD       FUSION
# 7             2023    AUDI         Q5 E
# 8             2014    FORD        C-MAX
# 14            2017    FORD        C-MAX
# 15            2020     KIA         NIRO
# ...            ...     ...          ...
# 130377        2019     BMW         530E
# 130385        2016    AUDI           A3
# 130390        2023    JEEP     WRANGLER
# 130407        2017  TOYOTA  PRIUS PRIME
# 130437        2021     BMW         530E
#
# [16379 rows x 3 columns]

# %%
import seaborn as sns
sns.countplot(data=notEligibleCars, x = 'Model',width=0.4)
# Out:
# <Axes: xlabel='Model', ylabel='count'>

# %%
# ● Get all TESLA cars with the model year, and model type made in Bothell City.
tesla_Bothell=tesla[tesla['City'] == "Bothell"]
tesla_Bothell[['Model Year','Model']]
# Out:
#         Model Year     Model
# 36            2022   SORENTO
# 39            2020   MODEL 3
# 56            2017      LEAF
# 217           2022   MODEL 3
# 218           2022   MODEL Y
# ...            ...       ...
# 130001        2022    ESCAPE
# 130074        2022      NIRO
# 130177        2018  PACIFICA
# 130295        2022   MODEL 3
# 130392        2018   MODEL 3
#
# [4024 rows x 2 columns]

# %%
# ● Get all the cars that have an electric range of more than 100, and were made after 2015

for i,row in tesla.iterrows():
    if int(row['Model Year']) > 2015:
        if int(row['Electric Range']) > 100:
            print(row[['Make',"Model"]])
# Out:
# Make       TESLA
# Model    MODEL X
# Name: 0, dtype: object
# Make       TESLA
# Model    MODEL 3
# Name: 2, dtype: object
# Make       TESLA
# Model    MODEL S
# Name: 4, dtype: object
# Make       TESLA
# Model    MODEL 3
# Name: 12, dtype: object
# Make       TESLA
# Model    MODEL 3
# Name: 13, dtype: object
# Make     CHEVROLET
# Model      BOLT EV
# Name: 19, dtype: object
# Make       TESLA
# Model    MODEL 3
# Name: 20, dtype: object
# Make     NISSAN
# Model      LEAF
# Name: 23, dtype: object
# Make     NISSAN
# Model      LEAF
# Name: 27, dtype: object
# Make       TESLA
# Model    MODEL 3
# Name: 28, dtype: object
# Make       TESLA
# Model    MODEL Y
# Name: 30, dtype: object
# Make       TESLA
# Model    MODEL 3
# Name: 31, dtype: object
# Make       TESLA
# Model    MODEL 3
# Name: 32, dtype: object
# Make     NISSAN
# Model      LEAF
# Name: 34, dtype: object
# Make       TESLA
# Model    MODEL 3
# Name: 35, dtype: object
# Make     CHEVROLET
# Model      BOLT EV
# ...

# %%
# ● Draw plots to show the distribution between city and electric vehicle type
pd.crosstab(tesla['City'],tesla['Electric Vehicle Type'], 
             normalize='index').plot.bar(stacked=True)
# Out:
# <Axes: xlabel='City'>

# %%
sns.histplot(binwidth=1,
            x=tesla['City'],
            hue=tesla['Electric Vehicle Type'],
            data=tesla,
            stat="count",
            multiple="dodge")
# Out:
# <Axes: xlabel='City', ylabel='Count'>
